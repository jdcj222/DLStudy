# %% [markdown]
# <a href="https://colab.research.google.com/github/jdcj222/DLStudy/blob/master/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # !cat /etc/*lease
# Out:
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=18.04
# DISTRIB_CODENAME=bionic
# DISTRIB_DESCRIPTION="Ubuntu 18.04.3 LTS"
# NAME="Ubuntu"
# VERSION="18.04.3 LTS (Bionic Beaver)"
# ID=ubuntu
# ID_LIKE=debian
# PRETTY_NAME="Ubuntu 18.04.3 LTS"
# VERSION_ID="18.04"
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# VERSION_CODENAME=bionic
# UBUNTU_CODENAME=bionic

# %%
# !apt update
# Out:
# Hit:1 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:3 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:4 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:6 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Ign:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:9 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:11 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ...

# %%
# !apt install -y imagemagick
# !convert
# Out:
# E: dpkg was interrupted, you must manually run 'dpkg --configure -a' to correct the problem.
# /bin/bash: convert: command not found

# %%
# !wget https://imagemagick.org/image/wizard.jpg
# Out:
# --2019-09-24 11:00:09--  https://imagemagick.org/image/wizard.jpg
# Resolving imagemagick.org (imagemagick.org)... 198.72.81.86
# Connecting to imagemagick.org (imagemagick.org)|198.72.81.86|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23358 (23K) [image/jpeg]
# Saving to: ‘wizard.jpg’
#
# wizard.jpg          100%[===================>]  22.81K  --.-KB/s    in 0.1s
#
# 2019-09-24 11:00:10 (154 KB/s) - ‘wizard.jpg’ saved [23358/23358]

# %%
# !convert wizard.jpg wizard.png
# !convert wizard.jpg wizard.bmp
# !ls -alsh wi
# Out:
# /bin/bash: convert: command not found
# /bin/bash: convert: command not found
# ls: cannot access 'wi': No such file or directory

# %%
# !identify -verbose wizard.jpg
# !identify wizard.jpg
# Out:
# /bin/bash: identify: command not found
# /bin/bash: identify: command not found

# %%
# !convert wizard.jpg -resize 64x64 wizard_s.jpg
# !ls -alsh wi*
# Out:
# /bin/bash: convert: command not found
# 24K -rw-r--r-- 1 root root 23K Mar  1  2019 wizard.jpg

# %%
# !convert wizard.jpg -crop 40x50+100+80 wizard_c.jpg
# Out:
# /bin/bash: convert: command not found

# %%
# !convert wizard.jpg -crop 40x50+130+130 wizard_c.jpg
# Out:
# /bin/bash: convert: command not found

# %%
# !ls *.jpg
# !mkdir converted
# Out:
# wizard.jpg

# %%
# %%bash
# mkdir converted
# for i in $(ls *.jpg); do
#   convert $i -resize 6464 converted/$i
# done
# ls converted
# Out:
# mkdir: cannot create directory ‘converted’: File exists
# bash: line 3: convert: command not found

# %%
# !git clone https://github.com/anishathalye/neural-style.git
# !wget http://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat
# Out:
# Cloning into 'neural-style'...
# remote: Enumerating objects: 292, done.
# remote: Total 292 (delta 0), reused 0 (delta 0), pack-reused 292
# Receiving objects: 100% (292/292), 2.63 MiB | 4.68 MiB/s, done.
# Resolving deltas: 100% (158/158), done.
# --2019-09-24 11:05:16--  http://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat
# Resolving www.vlfeat.org (www.vlfeat.org)... 64.90.48.57
# Connecting to www.vlfeat.org (www.vlfeat.org)|64.90.48.57|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 534904783 (510M)
# Saving to: ‘imagenet-vgg-verydeep-19.mat’
#
# imagenet-vgg-veryde 100%[===================>] 510.12M  19.9MB/s    in 26s
#
# 2019-09-24 11:05:42 (19.4 MB/s) - ‘imagenet-vgg-verydeep-19.mat’ saved [534904783/534904783]

# %%
# !pip install scipy==1.1.0

# %cd /content/neural-style/
# !python neural_style.py --content ./examples/1-content.jpg --styles ./examples/2-style1.jpg --output ./o1.jpg
# Out:
# ...
# /content/neural-style
# WARNING:tensorflow:From /content/neural-style/vgg.py:9: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /content/neural-style/vgg.py:11: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-09-24 11:06:15.234342: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-09-24 11:06:15.234623: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x12d92c0 executing computations on platform Host. Devices:
# 2019-09-24 11:06:15.234663: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-09-24 11:06:15.236909: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# ...

# %%
# %cd /content/neural-style/
# !python neural_style.py --content ./getamped.png --styles ./maxresdefault.jpg --output ./o2.jpg
# Out:
# /content/neural-style
# WARNING:tensorflow:From /content/neural-style/vgg.py:9: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /content/neural-style/vgg.py:11: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-09-24 11:27:01.682856: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-09-24 11:27:01.683147: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2bc52c0 executing computations on platform Host. Devices:
# 2019-09-24 11:27:01.683200: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-09-24 11:27:01.685531: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# ...
